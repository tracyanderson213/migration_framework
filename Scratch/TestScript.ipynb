# %%
df = spark.read.csv("/FileStore/tables/supplier.csv", header=True, inferSchema=True)
# df.write.format("delta").saveAsTable("supplier")

# %%
display(df)

# %%
# %sql
select * from it.migration_config.table_migration_config where process_group = 'TPCH_foreign_catalog'

-- update it.migration_config.table_migration_config set process_group = 'TPCH_foreign_catalog' where process_group = 'TPCH_POC'

# %%
# %sql
